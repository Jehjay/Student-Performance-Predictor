# %% [markdown]
# # Linear_Regression

# %% [markdown]
# ### IMPORT NECESSARY PACKAGES

# %%
# %matplotlib inline
import numpy as np, pandas as pd, matplotlib.pyplot as plt
import pathlib
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')  # Hide warnings for cleaner outputs

# %% [markdown]
# ### LOAD THE CSV FILE INTO A DATAFRAME

# %% [markdown]
# #### FOR MATH

# %%
MATH_COURSE_FILE_PATH = pathlib.Path.cwd().joinpath('student-mat.csv')
Student_math_course_df = pd.read_csv(MATH_COURSE_FILE_PATH, sep=';')
print(Student_math_course_df.info())
Student_math_course_df.head()

# %%
Student_math_course_df.describe()

# %%
print(Student_math_course_df.shape)

# %%
math_course_df_column_names = list(Student_math_course_df.columns.values)
print(math_course_df_column_names)

#OR
#list(Student_math_course_df)

# %% [markdown]
# #### FOR PORTUGUESE

# %%
PORTUGUESE_COURSE_FILE_PATH = pathlib.Path.cwd().joinpath('student-por.csv')
Student_portuguese_course_df = pd.read_csv(PORTUGUESE_COURSE_FILE_PATH, sep=';')
print(Student_portuguese_course_df.info())
Student_portuguese_course_df.head()

# %%
Student_portuguese_course_df.describe()

# %%
print(Student_portuguese_course_df.shape)

# %%
portuguese_course_df_column_names = list(Student_portuguese_course_df.columns.values)
print(portuguese_course_df_column_names)

#OR
#list(Student_portuguese_course_df)

# %% [markdown]
# ### SHOW ALL ROWS

# %% [markdown]
# #### FOR MATH

# %%
pd.set_option("display.max_rows",None)
pd.set_option("display.max_rows",None)

# %% [markdown]
# #### FOR PORTUGUESE

# %%
Student_math_course_df

# %%
Student_portuguese_course_df

# %% [markdown]
# ### RESET TO SHOW DEFAULT NUMBER OF ROWS

# %%
pd.reset_option("display.max_rows")
pd.reset_option("display.max_rows")

# %% [markdown]
# #### FOR MATH

# %%
for col in Student_math_course_df.columns:
    print(col)
    print(Student_math_course_df[col].value_counts())

# %% [markdown]
# #### FOR PORTUGUESE

# %%
for col in Student_portuguese_course_df.columns:
    print(col)
    print(Student_portuguese_course_df[col].value_counts())

# %% [markdown]
# ### CREATING THE TARGET & EXPLANATORY VARIABLE

# %% [markdown]
# #### FOR MATH

# %%
X_math = Student_math_course_df.drop('G3', axis = 'columns')
y_math = Student_math_course_df['G3']

# %% [markdown]
# #### CREATE
# #### 1. A FUNCTION TO CHANGE THE [G1, G2] columns ACCORDING TO A RANGE based on the Erasmus grade conversion system
# #### 2. A FUNCTION FOR ONE HOT ENCONDING THE ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'] columns.

# %%
def student_performance_preprocess_onehot(X):
    X_math = X 
    #convert to bool
    to_bool = ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
    # function to convert to bool
    def convert_fill_bool (val):
        if val == 'yes': return 1
        elif val == 'Yes': return 1
        else: return 0
        
    for col in to_bool:
        X_math[col] = X_math[col].apply(convert_fill_bool)
    return X_math

# %%
X_math = student_performance_preprocess_onehot(X_math)
Stundent_math_course_df = pd.concat([y_math,X_math], axis = 'columns')
# .dropna()
Student_math_course_df.head()

# %%
def student_performance_preprocess_grade(X):
    X_math = X 
    # grading columns
    grade = ['G1', 'G2']
    def erasmus_grade_range (val):
        if (0<val<=9) : return 5
        if (10<val<=11) : return 4
        if (12<val<=13) : return 3
        if (14<val<=15) : return 2
        if (15<val<=20) : return 1
        else: return np.nan
        
    for column in grade:
        X_math[column] = X_math[column].apply(erasmus_grade_range)
    return X_math

# %%
X_math = student_performance_preprocess_grade(X_math)
Student_math_course_df = pd.concat([y_math,X_math], axis = 'columns')
# .dropna()
Student_math_course_df.head()

# %% [markdown]
# #### FOR PORTUGUESE

# %%
X_port = Student_portuguese_course_df.drop('G3', axis = 'columns')
y_port = Student_portuguese_course_df['G3']

# %% [markdown]
# #### CREATE
# #### 1. A FUNCTION TO CHANGE THE [G1, G2] columns ACCORDING TO A RANGE based on the Erasmus grade conversion system
# #### 2. A FUNCTION FOR ONE HOT ENCONDING THE ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic'] columns.

# %%
def student_performance_preprocess_onehot(X):
    X_port = X 
    #convert to bool
    to_bool = ['schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic']
    # function to convert to bool
    def convert_fill_bool (val):
        if val == 'yes': return 1
        elif val == 'Yes': return 1
        else: return 0
        
    for col in to_bool:
        X_port[col] = X_port[col].apply(convert_fill_bool)
    return X_port

# %%
X_port = student_performance_preprocess_onehot(X_port)
Student_portuguese_course_df = pd.concat([y_port,X_port], axis = 'columns')
# .dropna()
Student_portuguese_course_df.head()

# %%
def student_performance_preprocess_grade(X):
    X_port = X
    # grading columns
    grade = ['G1', 'G2']
    def erasmus_grade_range (val):
        if (0<val<=9) : return 5
        if (10<val<=11) : return 4
        if (12<val<=13) : return 3
        if (14<val<=15) : return 2
        if (15<val<=20) : return 1
        else: return np.nan
        
    for column in grade:
        X_port[column] = X_port[column].apply(erasmus_grade_range)
    return X_port

# %%
X_port = student_performance_preprocess_grade(X_port)
Student_portuguese_course_df = pd.concat([y_port,X_port], axis = 'columns')
# .dropna()
Student_portuguese_course_df.head()

# %% [markdown]
# ### PRE-PROCESSING

# %% [markdown]
# #### FOR MATH AND FOR PORTUGUESE

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE school

# %%
# function for swchool one hot enconding
def school_one_hot(val):
    if val == 'GP' or val == 'gp':
        val = 1
    elif val == 'MS' or val == 'ms':
        val = 0
    return val

# %%
Student_math_course_df['school'] = Student_math_course_df['school'].apply(school_one_hot)
Student_portuguese_course_df['school'] = Student_portuguese_course_df['school'].apply(school_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE sex

# %%
# function for Gender one hot enconding
def gender_one_hot(val):
    if val == 'F' or val == 'f':
        val = 0
    elif val == 'M' or val == 'm':
        val = 1
    return val

# %%
Student_math_course_df['sex'] = Student_math_course_df['sex'].apply(gender_one_hot)
Student_portuguese_course_df['sex'] = Student_portuguese_course_df['sex'].apply(gender_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION TO CHANGE THE age ACCORDING TO RANGE

# %%
def convert_age_range (val):
    if (5<val<=9) : return 1
    if (10<val<=14) : return 2
    if (15<val<=19) : return 3
    if (20<val<=24) : return 4
    else: return np.nan

# %%
Student_math_course_df['age'] = Student_math_course_df['age'].apply(convert_age_range)
Student_portuguese_course_df['age'] = Student_portuguese_course_df['age'].apply(convert_age_range)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE address

# %%
# function for adress one hot enconding
def address_one_hot(val):
    if val == 'U' or val == 'u':
        val = 1
    elif val == 'R' or val == 'r':
        val = 0
    return val

# %%
Student_math_course_df['address'] = Student_math_course_df['address'].apply(address_one_hot)
Student_portuguese_course_df['address'] = Student_portuguese_course_df['address'].apply(address_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE famsize

# %%
# function for adress one hot enconding
def famsize_one_hot(val):
    if val == 'LE3' or val == 'ls3':
        val = 1
    elif val == 'GT3' or val == 'gt3':
        val = 0
    return val

# %%
Student_math_course_df['famsize'] = Student_math_course_df['famsize'].apply(famsize_one_hot)
Student_portuguese_course_df['famsize'] = Student_portuguese_course_df['famsize'].apply(famsize_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE Pstatus

# %%
# function for adress one hot enconding
def Pstatus_one_hot(val):
    if val == 'T' or val == 't':
        val = 1
    elif val == 'A' or val == 'a':
        val = 0
    return val

# %%
Student_math_course_df['Pstatus'] = Student_math_course_df['Pstatus'].apply(Pstatus_one_hot)
Student_portuguese_course_df['Pstatus'] = Student_portuguese_course_df['Pstatus'].apply(Pstatus_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE Mjob

# %%
# function for adress one hot enconding
def Mjob_one_hot(val):
    if val == 'teacher' : return 1
    if val == 'health' : return 2
    if val == 'services' : return 3
    if val == 'at_home' : return 4
    if val == 'other' : return 5
    else: return np.nan

# %%
Student_math_course_df['Mjob'] = Student_math_course_df['Mjob'].apply(Mjob_one_hot)
Student_portuguese_course_df['Mjob'] = Student_portuguese_course_df['Mjob'].apply(Mjob_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE Fjob

# %%
# function for adress one hot enconding
def Fjob_one_hot(val):
    if val == 'teacher' : return 1
    if val == 'health' : return 2
    if val == 'services' : return 3
    if val == 'at_home' : return 4
    if val == 'other' : return 5
    else: return np.nan

# %%
Student_math_course_df['Fjob'] = Student_math_course_df['Fjob'].apply(Fjob_one_hot)
Student_portuguese_course_df['Fjob'] = Student_portuguese_course_df['Fjob'].apply(Fjob_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE reason

# %%
# function for adress one hot enconding
def reason_one_hot(val):
    if val == 'home' : return 1
    if val == 'reputation' : return 2
    if val == 'course' : return 3
    if val == 'other' : return 4
    else: return np.nan

# %%
Student_math_course_df['reason'] = Student_math_course_df['reason'].apply(reason_one_hot)
Student_portuguese_course_df['reason'] = Student_portuguese_course_df['reason'].apply(reason_one_hot)

# %% [markdown]
# #### CREATE A FUNCTION FOR ONE HOT ENCONDING THE guardian

# %%
# function for adress one hot enconding
def guardian_one_hot(val):
    if val == 'father' : return 1
    if val == 'mother' : return 2
    if val == 'other' : return 3
    else: return np.nan

# %%
Student_math_course_df['guardian'] = Student_math_course_df['guardian'].apply(guardian_one_hot)
Student_portuguese_course_df['guardian'] = Student_portuguese_course_df['guardian'].apply(guardian_one_hot)

# %%
for col in Student_math_course_df.columns:
    print(col)
    print(Student_math_course_df[col].value_counts())

# %%
for col in Student_portuguese_course_df.columns:
    print(col)
    print(Student_portuguese_course_df[col].value_counts())

# %% [markdown]
# ### CHECK IF ANY COLUMN HAS MISSING DATA

# %% [markdown]
# #### FOR MATH

# %%
Student_math_course_df.head()

# %%
#math_course_is_na_df = Stundent_math_course_df.isna()
#print(math_course_is_na_df)
Student_math_course_df.isna().sum()

# %% [markdown]
# #### FOR PORTUGUESE

# %%
Student_portuguese_course_df.head()

# %%
#port_course_is_na_df = Stundent_portuguese_course_df.isna()
#print(port_course_is_na_df)
Student_portuguese_course_df.isna().sum()

# %% [markdown]
# ### CREATE A FUNCTION TO REMOVE NaN

# %% [markdown]
# #### FOR MATH

# %%
def remove_nan(x):
    if x == 'NaN':
        return 0
    else:
        return x

# %%
Student_math_course_df['age'] = Student_math_course_df['age'].apply(remove_nan)
Student_math_course_df['G1'] = Student_math_course_df['G1'].apply(remove_nan)
Student_math_course_df['G2'] = Student_math_course_df['G2'].apply(remove_nan)

# %%
Stundent_math_course_df['age'] = Stundent_math_course_df['age'].fillna(0)
Stundent_math_course_df['G1'] = Stundent_math_course_df['G1'].fillna(0)
Stundent_math_course_df['G2'] = Stundent_math_course_df['G2'].fillna(0)

# %%
Stundent_math_course_df.isna().sum()

# %% [markdown]
# #### FOR PORTUGUESE

# %%
def remove_nan(x):
    if x == 'NaN':
        return 0
    else:
        return x

# %%
Student_portuguese_course_df['age'] = Student_portuguese_course_df['age'].apply(remove_nan)
Student_portuguese_course_df['G1'] = Student_portuguese_course_df['G1'].apply(remove_nan)
Student_portuguese_course_df['G2'] = Student_portuguese_course_df['G2'].apply(remove_nan)

# %%
Student_portuguese_course_df['age'] = Student_portuguese_course_df['age'].fillna(0)
Student_portuguese_course_df['G1'] = Student_portuguese_course_df['G1'].fillna(0)
Student_portuguese_course_df['G2'] = Student_portuguese_course_df['G2'].fillna(0)

# %%
Student_portuguese_course_df.isna().sum()

# %% [markdown]
# ### CONVERT TO FLOAT

# %% [markdown]
# #### FOR MATH

# %%
Student_math_course_df.info()

# %%
Student_math_course_df[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']] = Student_portuguese_course_df.astype(float) 

# OR
#Stundent_portuguese_course_df.astype(float)

# %%
Student_math_course_df.info()

# %%
dtypeCount =[Student_math_course_df.iloc[:,i].apply(type).value_counts() for i in range(Student_math_course_df.shape[1])]
dtypeCount

# %%
Student_math_course_df.dropna()

# %%
Student_math_course_df.head()

# %% [markdown]
# ### CHECK AND HANDLE DUPLICATES IF ANY

# %%
if_duplicate = Student_math_course_df[Student_math_course_df.duplicated(keep='last')]
if_duplicate.shape

# %% [markdown]
# ### CLASS DISTRIBUTION WITH AND WITHOUT DUPLICATES

# %%
print("WITH DUPLICATES : ", Student_math_course_df.shape)
Student_math_course_df.drop_duplicates(inplace=True)
print("WITHOUT DUPLICATES : ", Student_math_course_df.shape)

# %% [markdown]
# ### BUILD YOUR MODEL

# %%
# print(X)
X = Student_math_course_df.drop(['G3'], axis='columns')
y = Student_math_course_df.loc[:, 'G3']

# %% [markdown]
# ### EXPLANATORY VARIABLE

# %%
list(X)

# %%
X.info()

# %%
dtypeCountX =[X.iloc[:,i].apply(type).value_counts() for i in range(X.shape[1])]
dtypeCountX

# %% [markdown]
# ### TARGET VARIABLE

# %%
list(y)

# %%
y

# %% [markdown]
# ### THE TRAIN TEST SPLIT FOR MATH

# %%
from sklearn.model_selection import train_test_split

X_mat_lin_train, X_mat_lin_test, y_mat_lin_train, y_mat_lin_test = train_test_split(X, y)

print(len(X_mat_lin_train), len(X_mat_lin_test), len(y_mat_lin_train), len(y_mat_lin_test))

# %% [markdown]
# ### LINEAR REGRESSION MODEL FOR MATH

# %%
from sklearn.linear_model import LinearRegression

# Now the linear regression model
linreg_math = LinearRegression()
linreg_math.fit(X_mat_lin_train, y_mat_lin_train)
#predicted_success = linreg_math.predict([['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']])
predicted_success_math = linreg_math.predict(X_mat_lin_test)
predicted_success_math

# %%
len(predicted_success_math)

# %%
#regression coefficients
print('Coefficients for Math : ', linreg_math.coef_)

# variance score
print('Variance score for Math : {}'.format(linreg_math.score(X_mat_lin_test, y_mat_lin_test)))

# %% [markdown]
# ### PLOTTING FOR THE RESIDUAL ERROR

# %%
from datetime import date

#setting plot style
plt.style.use('fivethirtyeight')

#plot residual erors in training data
plt.scatter(linreg_math.predict(X_mat_lin_train), linreg_math.predict(X_mat_lin_train)-y_mat_lin_train, color="green", label="Train data")

#plot residual erors in test data
plt.scatter(linreg_math.predict(X_mat_lin_test), linreg_math.predict(X_mat_lin_test)-y_mat_lin_test, color="blue", label="Test data")

#plotting line for zero residdual error
plt.hlines(y=0, xmin=0, xmax=50, linewidth=2)

#plotting legend
plt.legend(loc="upper right")
#plot title
plt.title("Residual errors for Math")
copyright = "\u00A9" + " " + str(date.today().year) + " " + "JM Consulting"
plt.text(0.5, 0.5, copyright, alpha=0.3, fontsize=25, rotation=25, ha='center', va='center', transform=plt.gca().transAxes)
plt.show()

# %% [markdown]
# ### EVALUATING THE LINEAR REGRESSION MODEL WITH ROOT MEAN SQUARE ERROR (RMSE)

# %%
from sklearn.metrics import mean_squared_error
rmse_math_lin_reg = mean_squared_error(y_mat_lin_test, predicted_success_math, squared=False)
rmse_math_lin_reg

# %% [markdown]
# ### FOR PORTUGUESE

# %%
Student_portuguese_course_df.info()

# %%
Student_portuguese_course_df[['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2', 'G3']] = Student_portuguese_course_df.astype(float) 

# OR
#Student_portuguese_course_df.astype(float)

# %%
Student_portuguese_course_df.info()

# %%
dtypeCount =[Student_portuguese_course_df.iloc[:,i].apply(type).value_counts() for i in range(Student_portuguese_course_df.shape[1])]
dtypeCount

# %%
Student_portuguese_course_df.dropna()

# %%
Student_portuguese_course_df.head()

# %% [markdown]
# ### CHECK AND HANDLE DUPLICATES IF ANY

# %%
if_duplicate = Student_portuguese_course_df[Student_portuguese_course_df.duplicated(keep='last')]
if_duplicate.shape

# %% [markdown]
# ### CLASS DISTRIBUTION WITH AND WITHOUT DUPLICATES

# %%
print("WITH DUPLICATES : ", Student_portuguese_course_df.shape)
Student_portuguese_course_df.drop_duplicates(inplace=True)
print("WITHOUT DUPLICATES : ", Student_portuguese_course_df.shape)

# %%
# print(X)
X = Student_portuguese_course_df.drop(['G3'], axis='columns')
y = Student_portuguese_course_df.loc[:, 'G3']

# %% [markdown]
# ### EXPLANATORY VARIABLE

# %%
list(X)

# %% [markdown]
# ### TARGET VARIABLE

# %%
list(y)

# %% [markdown]
# ### THE TRAIN TEST SPLIT FOR PORTUGUESE

# %%
from sklearn.model_selection import train_test_split

X_port_train, X_port_test, y_port_train, y_port_test = train_test_split(X, y)

print(len(X_port_train), len(X_port_test), len(y_port_train), len(y_port_test))

# %% [markdown]
# ### BUILD YOUR MODEL

# %% [markdown]
# ### LINEAR REGRESSION MODEL FOR PORTUGUESE

# %%
# Now the linear regression model
linreg_port = LinearRegression()
linreg_port.fit(X_port_train, y_port_train)
#predicted_success = linreg_port.predict([['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu', 'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime', 'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2']])
predicted_success_portuguese = linreg_math.predict(X_port_test)
predicted_success_portuguese

# %%
#regression coefficients
print('Coefficients for Portuguese: ', linreg_port.coef_)

# variance score
print('Variance score for Portuguese: {}'.format(linreg_port.score(X_port_test, y_port_test)))

# %% [markdown]
# ### PLOTTING FOR THE RESIDUAL ERROR

# %%
from datetime import date

#setting plot style
plt.style.use('fivethirtyeight')

#plot residual erors in training data
plt.scatter(linreg_port.predict(X_port_train), linreg_port.predict(X_port_train)-y_port_train, color="green", label="Train data")

#plot residual erors in test data
plt.scatter(linreg_port.predict(X_port_test), linreg_port.predict(X_port_test)-y_port_test, color="blue", label="Test data")

#plotting line for zero residual error
plt.hlines(y=0, xmin=0, xmax=50, linewidth=2)

#plotting legend
plt.legend(loc="upper right")
#plot title
plt.title("Residual errors for Portuguese ")
copyright = "\u00A9" + " " + str(date.today().year) + " " + "JM Consulting"
plt.text(0.5, 0.5, copyright, alpha=0.3, fontsize=25, rotation=25, ha='center', va='center', transform=plt.gca().transAxes)
plt.show()

# %% [markdown]
# ### EVALUATING THE LINEAR REGRESSION MODEL WITH ROOT MEAN SQUARE ERROR (RMSE)

# %%
from sklearn.metrics import mean_squared_error
rmse_port_lin_reg = mean_squared_error(y_port_test, predicted_success_portuguese, squared=False)
rmse_port_lin_reg
